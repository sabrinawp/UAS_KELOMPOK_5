# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style='darkgrid')

# %%
df = pd.read_csv('Dataset_tweet.csv', header=None, names=['label','text'], skiprows=1, engine='python')
df
# Out:
#                      label                                               text
# 1594719276157763586      0  Ya Allah gue stres capek lelah menghadapi tuga...
# 1594714011647741952      2  @yusuf_dumdum Pendengki Pak Anies terlihat mak...
# 1594703827076546560      0  maaf y gwe lg rada stres, tugas dgp sm bindo b...
# 1594703041122701312      0                 @tanyakanrl stres banyak tugas 😮‍💨
# 1594694347144003596      0  @yailahwaz masi panas sntai dlu anget sruput d...
# ...                    ...                                                ...
# 1593880987447894016      0  when lu stres liat tugas sama ulangan buat min...
# 1593855171515551744      3  Sebagian orang menganggap bahwa menjadi ibu ad...
# 1593852441660751872      0  sama tugas di sbux biar ga stres soalnya ditin...
# 1593830777305067520      3  10 Kebiasaan untuk Meredakan Stres, Bukan Cuma...
# 1593826040232775681      3  10 Kebiasaan untuk Meredakan Stres, Bukan Cuma...
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1594719276157763586 to 1593826040232775681
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   100 non-null    int64
#  1   text    100 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
df.describe()
# Out:
#             label
# count  100.000000
# mean     0.950000
# std      1.402559
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      3.000000
# max      4.000000

# %%
df.groupby('label').describe()
# Out:
#        text
#       count unique                                                top freq
# label
# 0        67     65  🌙 stres liat persentase turnitin? joki tugas d...    3
# 1         2      2  Selamat! Anda sukses buat saya stres, mood amb...    1
# 2         2      2  @yusuf_dumdum Pendengki Pak Anies terlihat mak...    1
# 3        27     24  RT @zonaminsung: 🧡 haloo, aku lagi cari au yan...    4
# 4         2      2  Gua mandi sekali sehari biasanya. Tapi kalo lg...    1

# %%
df['length'] = df['text'].apply(len)

# %%
df.hist(column='length', by='label', bins=50,figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>],
#        [<AxesSubplot:title={'center':'4'}>, <AxesSubplot:>]], dtype=object)

# %%
fig1 = sns.barplot(x='label',y='length',data = df)
plt.title('Average Word Length vs label')
plot = fig1.get_figure()

# %%
fig2 = sns.countplot(x= 'label',data = df)
plt.title('Label Counts')
plot = fig2.get_figure()

# %%
count_class_0, count_class_1, count_class_2, count_class_3, count_class_4 = df.label.value_counts()

# %%
df_class_0 = df[df['label'] == 0]
df_class_1 = df[df['label'] == 1]
df_class_2 = df[df['label'] == 2]
df_class_3 = df[df['label'] == 3]
df_class_4 = df[df['label'] == 4]

# %%
df_class_0
# Out:
#                      label                                               text  \
# 1594719276157763586      0  Ya Allah gue stres capek lelah menghadapi tuga...
# 1594703827076546560      0  maaf y gwe lg rada stres, tugas dgp sm bindo b...
# 1594703041122701312      0                 @tanyakanrl stres banyak tugas 😮‍💨
# 1594694347144003596      0  @yailahwaz masi panas sntai dlu anget sruput d...
# 1594693757613789187      0  maaf ya kalo lewat, lagi stres tugas, butuh pe...
# ...                    ...                                                ...
# 1593933264645128192      0  Tidur ae si. Pentingin tidur lo drpd tugas yg ...
# 1593927239594221568      0  Aku mikirin tugas aja stres, apalagi disuruh m...
# 1593920875384168449      0  @convomfs gue pake minyak telon bukan buat pen...
# 1593880987447894016      0  when lu stres liat tugas sama ulangan buat min...
# 1593852441660751872      0  sama tugas di sbux biar ga stres soalnya ditin...
#
#                      length
# ...

# %%
df_class_1
# Out:
#                      label                                               text  \
# 1594643151817699329      1  Selamat! Anda sukses buat saya stres, mood amb...
# 1594286468192956416      1  my hair journey \n- jan/sep 2021 blonde (stres...
#
#                      length
# 1594643151817699329     102
# 1594286468192956416     190

# %%
df_class_2
# Out:
#                      label                                               text  \
# 1594714011647741952      2  @yusuf_dumdum Pendengki Pak Anies terlihat mak...
# 1594369437452623872      2  @DoankWarto Pendengki Pak Anies semakin stres ...
#
#                      length
# 1594714011647741952     102
# 1594369437452623872      93

# %%
df_class_3
# Out:
#                      label                                               text  \
# 1594657055146737665      3  KULIAH BUKAN STRES TUGAS NYA TP STRES TEMEN KE...
# 1594564437582962689      3  RT @zonaminsung: 🧡 haloo, aku lagi cari au yan...
# 1594543156233900033      3  RT @zonaminsung: 🧡 haloo, aku lagi cari au yan...
# 1594519935405150208      3  RT @zonaminsung: 🧡 haloo, aku lagi cari au yan...
# 1594518119694811137      3  Hai Sahabat Ad Familia!\n\nKami sedang mengada...
# 1594517215352885248      3  Hai Sahabat Ad Familia!\n\nKami sedang mengada...
# 1594500676733702144      3  RT @zonaminsung: 🧡 haloo, aku lagi cari au yan...
# 1594498333044637696      3  🧡 haloo, aku lagi cari au yang minho jadi gig*...
# 1594456541934936065      3  RT @masih_kuat_kok: Diam di "gapapa" in aja, b...
# 1594444725599117312      3  Diam di "gapapa" in aja, bergerak stres semua....
# 1594353218212941824      3        Stres karna tugas ❌\nStres karna Jungkook ✅
# ...

# %%
df_class_4
# Out:
#                      label                                               text  \
# 1594602182405406722      4  Gua mandi sekali sehari biasanya. Tapi kalo lg...
# 1594213657353027584      4  lu kira lu doang yg stres apa, gw chat lu juga...
#
#                      length
# 1594602182405406722     244
# 1594213657353027584     132

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_class_2_over = df_class_2.sample(count_class_0, replace=True)
df_class_3_over = df_class_3.sample(count_class_0, replace=True)
df_class_4_over = df_class_4.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over,df_class_2_over, df_class_3_over, df_class_4_over], axis=0)

print('Random over-sampling:')
print(df_test_over.label.value_counts())
# Out:
# Random over-sampling:
# 0    67
# 1    67
# 2    67
# 3    67
# 4    67
# Name: label, dtype: int64

# %%
fig3 = sns.countplot(x= 'label',data = df_test_over)
plt.title('Label Counts')
plot = fig3.get_figure()

# %%
df_test_over.groupby('label').describe()
# Out:
#       length
#        count        mean        std    min    25%    50%    75%    max
# label
# 0       67.0  114.059701  66.588260   30.0   66.0   98.0  136.0  288.0
# 1       67.0  140.089552  43.930293  102.0  102.0  102.0  190.0  190.0
# 2       67.0   97.298507   4.529415   93.0   93.0   93.0  102.0  102.0
# 3       67.0  164.283582  87.209745   38.0   96.0  140.0  218.0  303.0
# 4       67.0  177.134328  55.350370  132.0  132.0  132.0  244.0  244.0

# %%
df_test_over
# Out:
#                      label                                               text  \
# 1594719276157763586      0  Ya Allah gue stres capek lelah menghadapi tuga...
# 1594703827076546560      0  maaf y gwe lg rada stres, tugas dgp sm bindo b...
# 1594703041122701312      0                 @tanyakanrl stres banyak tugas 😮‍💨
# 1594694347144003596      0  @yailahwaz masi panas sntai dlu anget sruput d...
# 1594693757613789187      0  maaf ya kalo lewat, lagi stres tugas, butuh pe...
# ...                    ...                                                ...
# 1594602182405406722      4  Gua mandi sekali sehari biasanya. Tapi kalo lg...
# 1594602182405406722      4  Gua mandi sekali sehari biasanya. Tapi kalo lg...
# 1594213657353027584      4  lu kira lu doang yg stres apa, gw chat lu juga...
# 1594213657353027584      4  lu kira lu doang yg stres apa, gw chat lu juga...
# 1594602182405406722      4  Gua mandi sekali sehari biasanya. Tapi kalo lg...
#
#                      length
# ...

# %%
! pip install Sastrawi

# %%
from textblob import TextBlob
import re
import nltk
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sasa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sasa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
df_test_over['text'] = df_test_over['text'].str.lower()


print('Case Folding Result : \n')
print(df_test_over['text'].head(100))
# Out:
# Case Folding Result :
#
# 1594719276157763586    ya allah gue stres capek lelah menghadapi tuga...
# 1594703827076546560    maaf  gwe lg rada stres tugas dgp sm bindo blo...
# 1594703041122701312                                   stres banyak tugas
# 1594694347144003596    masi panas sntai dlu anget sruput dkit nikmat ...
# 1594693757613789187    maaf ya kalo lewat lagi stres tugas butuh peny...
#                                              ...
# 1594286468192956416    my hair journey jansep blonde stres corona pat...
# 1594643151817699329    selamat anda sukses buat saya stres mood ambur...
# 1594643151817699329    selamat anda sukses buat saya stres mood ambur...
# 1594286468192956416    my hair journey jansep blonde stres corona pat...
# 1594286468192956416    my hair journey jansep blonde stres corona pat...
# Name: text, Length: 100, dtype: object

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
df_test_over['text'] = df_test_over['text'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df_test_over['text'] = df_test_over['text'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_test_over['text'] = df_test_over['text'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_test_over['text'] = df_test_over['text'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_test_over['text'] = df_test_over['text'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_test_over['text'] = df_test_over['text'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_test_over['text_list'] = df_test_over['text'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df_test_over['text_list'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 1594719276157763586    [ya, allah, gue, stres, capek, lelah, menghada...
# 1594703827076546560    [maaf, gwe, lg, rada, stres, tugas, dgp, sm, b...
# 1594703041122701312                               [stres, banyak, tugas]
# 1594694347144003596    [masi, panas, sntai, dlu, anget, sruput, dkit,...
# 1594693757613789187    [maaf, ya, kalo, lewat, lagi, stres, tugas, bu...
# Name: text_list, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah', 'lg'])

# %%
# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df_test_over['text_list2'] = df_test_over['text_list'].apply(stopwords_removal) 


print(df_test_over['text_list2'].head())
# Out:
# 1594719276157763586    [allah, gue, stres, capek, lelah, menghadapi, ...
# 1594703827076546560    [maaf, gwe, rada, stres, tugas, dgp, sm, bindo...
# 1594703041122701312                                       [stres, tugas]
# 1594694347144003596    [masi, panas, sntai, dlu, anget, sruput, dkit,...
# 1594693757613789187        [maaf, stres, tugas, butuh, penyegaran, otak]
# Name: text_list2, dtype: object

# %%
normalizad_word = pd.read_excel("normalisasi.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_test_over['text_list3'] = df_test_over['text_list2'].apply(normalized_term)

df_test_over['text_list3'].head()
# Out:
# 1594719276157763586    [allah, saya, stres, lelah, lelah, menghadapi,...
# 1594703827076546560    [maaf, gwe, rada, stres, tugas, dgp, sm, bindo...
# 1594703041122701312                                       [stres, tugas]
# 1594694347144003596    [masi, panas, sntai, dulu, anget, sruput, sedi...
# 1594693757613789187        [maaf, stres, tugas, butuh, penyegaran, otak]
# Name: text_list3, dtype: object

# %%
conda install -c conda-forge swifter
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_test_over['text_list3']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_test_over['text_list4'] = df_test_over['text_list3'].swifter.apply(get_stemmed_term)
print(df_test_over['text_list4'])
# Out:
# 562
# ------------------------
# allah : allah
# saya : saya
# stres : stres
# lelah : lelah
# menghadapi : hadap
# tugas : tugas
# iniiii : iniiii
# kangen : kangen
# nonton bareng : nonton bareng
# bareng : bareng
# maaf : maaf
# gwe : gwe
# rada : rada
# dgp : dgp
# sm : sm
# bindo : bindo
# bloman : bloman
# skli : skli
# masi : mas
# panas : panas
# sntai : sntai
# dulu : dulu
# anget : anget
# sruput : sruput
# sedikit : sedikit
# nikmat : nikmat
# pln : pln
# smbil : smbil
# mikirin : mikirin
# habis : habis
# sudah : sudah
# dingin : dingin
# butuh : butuh
# penyegaran : segar
# otak : otak
# bgst : bgst
# anj : anj
# smt : smt
# bnr : bnr
# banget : banget
# banyak : banyak
# tekanan : tekan
# minggu : minggu
# ditanyain : ditanyain
# progres : progres
# proposal : proposal
# aplikasi : aplikasi
# praktikum : praktikum
# belum : belum
# lpj : lpj
# an : an
# hadehhh : hadehhh
# bntr : bntr
# gila : gila
# bimbingan : bimbing
# konseling : konseling
# suru : suru
# ...

# %%
df_test_over
# Out:
#                      label                                               text  \
# 1594719276157763586      0  ya allah gue stres capek lelah menghadapi tuga...
# 1594703827076546560      0  maaf gwe lg rada stres tugas dgp sm bindo blom...
# 1594703041122701312      0                                 stres banyak tugas
# 1594694347144003596      0  masi panas sntai dlu anget sruput dkit nikmat ...
# 1594693757613789187      0  maaf ya kalo lewat lagi stres tugas butuh peny...
# ...                    ...                                                ...
# 1594602182405406722      4  gua mandi sekali sehari biasanya tapi kalo lg ...
# 1594602182405406722      4  gua mandi sekali sehari biasanya tapi kalo lg ...
# 1594213657353027584      4  lu kira lu doang yg stres apa gw chat lu juga ...
# 1594213657353027584      4  lu kira lu doang yg stres apa gw chat lu juga ...
# 1594602182405406722      4  gua mandi sekali sehari biasanya tapi kalo lg ...
#
#                      length  \
# ...

# %%
X = df_test_over['text']
y = df_test_over['label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
#Machine Learning Pipeline Random Forest
pipeline_rnf = Pipeline([
    ('bow',CountVectorizer(analyzer=stemmed_wrapper)), 
    ('tfidf', TfidfTransformer()),  # pembobotan dengan TF-IDF score
    ('classifier', RandomForestClassifier(n_estimators=100)), 
])
pipeline_rnf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function stemmed_wrapper at 0x0000020DD1D005E0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', RandomForestClassifier())])

# %%
#Machine Learning Pipeline Multinomial Naive Bayes
pipeline_mnb = Pipeline([
    ('bow',CountVectorizer(analyzer=stemmed_wrapper)),  
    ('tfidf', TfidfTransformer()),  # pembobotan dengan TF-IDF score
    ('classifier', MultinomialNB()),  
])
pipeline_mnb.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function stemmed_wrapper at 0x0000020DD1D005E0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
#Machine Learning Pipeline KNN
pipeline_knn = Pipeline([
    ('bow',CountVectorizer(analyzer=stemmed_wrapper)),  
    ('tfidf', TfidfTransformer()),  # pembobotan dengan TF-IDF score
    ('classifier', KNeighborsClassifier(n_neighbors=2)),  
])
pipeline_knn.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function stemmed_wrapper at 0x0000020DD1D005E0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', KNeighborsClassifier(n_neighbors=2))])

# %%
from sklearn import metrics

# %%
predictions_rnf = pipeline_rnf.predict(X_test)

print("==== Random Forest ====")
print(metrics.classification_report(predictions_rnf,y_test))
print ('\n')
print(metrics.confusion_matrix(predictions_rnf,y_test))
print(metrics.accuracy_score(predictions_rnf,y_test))
# Out:
# ==== Random Forest ====
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        18
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        14
#
#     accuracy                           1.00        67
#    macro avg       1.00      1.00      1.00        67
# weighted avg       1.00      1.00      1.00        67
#
#
#
# [[13  0  0  0  0]
#  [ 0 11  0  0  0]
#  [ 0  0 18  0  0]
#  [ 0  0  0 11  0]
#  [ 0  0  0  0 14]]
# 1.0

# %%
predictions_mnb = pipeline_mnb.predict(X_test)

print("==== Multinomial Naive Bayes ====")
print(metrics.classification_report(predictions_mnb,y_test))
print ('\n')
print(metrics.confusion_matrix(predictions_mnb,y_test))
print(metrics.accuracy_score(predictions_mnb,y_test))
# Out:
# ==== Multinomial Naive Bayes ====
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70         7
#            1       1.00      0.85      0.92        13
#            2       1.00      1.00      1.00        18
#            3       1.00      0.79      0.88        14
#            4       1.00      0.93      0.97        15
#
#     accuracy                           0.91        67
#    macro avg       0.91      0.91      0.89        67
# weighted avg       0.95      0.91      0.92        67
#
#
#
# [[ 7  0  0  0  0]
#  [ 2 11  0  0  0]
#  [ 0  0 18  0  0]
#  [ 3  0  0 11  0]
#  [ 1  0  0  0 14]]
# 0.9104477611940298

# %%
predictions_knn = pipeline_knn.predict(X_test)

print("==== KNN ====")
print(metrics.classification_report(predictions_knn,y_test))
print ('\n')
print(metrics.confusion_matrix(predictions_knn,y_test))
print(metrics.accuracy_score(predictions_knn,y_test))
# Out:
# ==== KNN ====
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.92      0.96        12
#            2       1.00      1.00      1.00        18
#            3       1.00      0.92      0.96        12
#            4       1.00      0.93      0.97        15
#
#     accuracy                           0.96        67
#    macro avg       0.95      0.95      0.95        67
# weighted avg       0.97      0.96      0.96        67
#
#
#
# [[10  0  0  0  0]
#  [ 1 11  0  0  0]
#  [ 0  0 18  0  0]
#  [ 1  0  0 11  0]
#  [ 1  0  0  0 14]]
# 0.9552238805970149
